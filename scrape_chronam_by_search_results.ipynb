# %% [markdown]
# # Scraping ChronAm Search Results for Relevant OCR URLs and Scraping Those URLs for Data
#
# To enter the relevant urls and other data into this notebook you must identify relevant search urls in ChronAm using your web browser. This notebook describes two parts to the process of getting every page with searched content from ChronAm into a dataframe. It accounts for ChronAm's rate limits: https://www.loc.gov/apis/json-and-yaml/working-within-limits/#rate-limits. This code was partially written with ChatGPT (GPT-4o).

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import time
from datetime import datetime, timedelta

# %% [markdown]
# ### 1) Scrape search results to get all pages with relevant results
#
# Copy and paste your search url as search_url.
#
# Then note the parameters in your search: rows and pages. Rows refers to the number of search results displayed per page. It appears in the url as "rows=". Replace its value with 1000. This is the max number of results allowed per search according to ChronAm's rate limits. Then refer to the page parameter. It appears in the url as "page=". change the page value to {}. This is a placeholder that will let us iterate over the number of pages per results.
#
# On that note, also look to your url search page in your browser. How many "Results" pages does it list? That number (plus one, since Python is funny that way) is the number of pages you need to iterate over.

# %%
# search URL to scrape, with a placeholder for the page number and max rows set to 1000
search_url = 'https://chroniclingamerica.loc.gov/search/pages/results/list/?date1=1800&rows=1000&searchType=basic&state=Minnesota&date2=1899&proxtext=star+spangled+banner&y=0&x=0&dateFilterType=yearRange&page={}&sort=date'

# %% [markdown]
# We'll also need the regex pattern for the subsequent urls in the search results. ChronAm urls that direct to a specific newspaper page have a consistent pattern: /lccn/sn_code/year-month-day/edition/sequence(page)/. The following regex object saved as page_pattern captures any combination of this url.
#
# And, we'll need to save the scraped urls and their accompanying titles in a list, so we'll need a shell of that list called scrape_results

# %%
# Regex pattern for ChronAm urls for specific newspaper pages
page_pattern = re.compile(r'/lccn/sn\d+/\d{4}-\d{2}-\d{2}/ed-\d/seq-\d+/')

# a shell for our scraped results
scrape_results = []

# %% [markdown]
# Next we'll need a function that sends requests to ChronAm's server and retrieves content from the search results. This function is also adapted to account for ChronAm's rate limits. Initially, it will not make more than 10 requests in 10 seconds. If the number of requests reaches 200 in a minute, it will also pause for 5 minutes. If somehow you still get a 429 error, it will revert to an exponential backoff with time limits for the backoff increasing every time you get a 429 error. This is the fastest way I can imagine working around ChronAm's rate limits.

# %%
# Function that sends requests with retry logic for handling 429 errors
def send_request_with_retry(url, retries=2, backoff_factor=2):
    global request_count, first_request_time
    
    # Check if this is the first request and set first_request_time to current present moment
    if request_count == 0:
        first_request_time = datetime.now()
    
    # screen for ChronAm's crawl limit (200 requests per 1 minute)
    if request_count >= 200:
        elapsed_time = datetime.now() - first_request_time
        if elapsed_time < timedelta(minutes=1):
            print("Crawl limit reached. Waiting for 5 minutes...")
            time.sleep(300)  # Wait for 5 minutes
            first_request_time = datetime.now()
            request_count = 0
    
    # Check for ChronAm's burst limit (10 requests per 10 seconds)
    if request_count > 0 and request_count % 10 == 0:
        print("Burst limit reached. Waiting for 5 seconds...")
        time.sleep(5)
    
    for i in range(retries):
        response = requests.get(url)
        
        # counter for the request count goes up
        request_count += 1
        print(f"Requests made: {request_count}")
        
        # if you get response code 200, hooray! The request was successful
        if response.status_code == 200:
            return response
        
        # if you get a 429 error, you're notified and the function adds to the backoff factor
        elif response.status_code == 429:
            print(f"Rate limit exceeded. Received 429 error. Retrying in {backoff_factor**i} seconds...")
            time.sleep(backoff_factor ** i)  # Exponential backoff
            
            # After hitting a 429 error, pause for 5 minutes
            if i == retries - 1:
                print("Too many retries. Waiting for 5 minutes...")
                time.sleep(300)
                
        else:
            print(f"Failed to retrieve {url}: {response.status_code}")
            return None
    return None

# Before you run this function, you'll need to set your initial these two initial variables
# request_count is the counter for requests to ChronAm's server
# first_request_time becomes the moment you run the program
request_count = 0
first_request_time = None

# %% [markdown]
# Okay, now with the function send_request_with_retry, we need to iterate over the number of pages per search results. How many Results pages are listed in your search? Make that (plus one, because Python is weird that way) your range. We also need to extract the relevant urls from the scraped HTML. The following code does these things.

# %%
# to keep track of how long the program takes to run
start_time = datetime.now()

# Iterate over the pages of your search results
for results_number in range(1, 3):
    # change the page= part of your url with the different numbers in your range
    url = search_url.format(results_number)
    
    # use our function on the iterating versions of your url to get regex matches
    scrape_content = send_request_with_retry(url)
    
    # Check if the scraped content was successful. If it isn't because it got errors more than twice, that page will be skipped. No sense in letting a broken link break your entire code.
    if scrape_content is None:
        print(f"Skipping page {results_number} due to repeated errors.")
        continue
    
    # Parse the HTML content from scraped_content using BeautifulSoup
    soup = BeautifulSoup(scrape_content.text, 'html.parser')
    
    # We only want the content with the <ul> label and class 'results_list'. This contains titles and urls to ChronAm pages containing your search term
    results_list = soup.find('ul', class_='results_list')
    
    # Check if results_list was found. It's unlikely, but if there's a bug in the HTML for a search result page, this will skip that page. No sense in breaking your code due to poorly coded HTML.
    if results_list is None:
        print(f"No results found on page {results_number}")
        continue
    
    # Find all <a> tags within the results_list that match our regex pattern for ChronAm newspaper pages.
    matching_links = results_list.find_all('a', href=page_pattern)
    
    # Iterate over the matching links and put their titles and urls into our shell list scrape_results
    for link in matching_links:
        link_text = link.get_text(strip=True)
    
        # Extract the matching string from link['href']
        match = page_pattern.search(link['href'])
        if match:
            # Use only the matched part of the href. Otherwise, you get a bunch of other url parts pertaining to the search results
            matched_href = match.group()
            # add the 'ocr' part to the url so it will take you straight to "scrapeable" newspaper content in the later step
            link_href = f"https://chroniclingamerica.loc.gov{matched_href}ocr/"
            scrape_results.append({'Link Title': link_text, 'URL': link_href})

    # Optionally, print progress. I like to do this so I know how far along I'm going.
    print(f"Page {results_number} processed.")

# Calculate and print the total elapsed time. This may be useful to help you know how long it takes to scrape.
end_time = datetime.now()
total_elapsed_time = end_time - start_time
print(f"Total elapsed time: {total_elapsed_time}")

# Convert our list of page titles and urls to a DataFrame
df = pd.DataFrame(scrape_results)
# Out:
# Requests made: 1
# Page 1 processed.
# Requests made: 2
# Page 2 processed.
# Total elapsed time: 0:00:00.455162

# %% [markdown]
# Hooray! Now let's review our dataframe.

# %%
df
# Out:
#                                              Link Title  \
# 0     The Minnesota pioneer. [volume](St. Paul, Minn...
# 1     The Minnesota pioneer. [volume](St. Paul, Minn...
# 2     Minnesota weekly times. [volume](St. Paul, Min...
# 3     The weekly Minnesotian. [volume](Saint Paul, M...
# 4     Minnesota weekly times. [volume](St. Paul, Min...
# ...                                                 ...
# 1431  Warren sheaf. [volume](Warren, Marshall County...
# 1432  The Sauk Centre herald.(Sauk Centre, Stearns C...
# 1433  The Saint Paul globe.(St. Paul, Minn.), Decemb...
# 1434  Grand Rapids herald-review. [volume](Grand Rap...
# 1435  The Saint Paul globe.(St. Paul, Minn.), Decemb...
#
#                                                     URL
# 0     https://chroniclingamerica.loc.gov/lccn/sn8302...
# 1     https://chroniclingamerica.loc.gov/lccn/sn8302...
# 2     https://chroniclingamerica.loc.gov/lccn/sn8502...
# 3     https://chroniclingamerica.loc.gov/lccn/sn8301...
# 4     https://chroniclingamerica.loc.gov/lccn/sn8502...
# ...                                                 ...
# 1431  https://chroniclingamerica.loc.gov/lccn/sn9005...
# 1432  https://chroniclingamerica.loc.gov/lccn/sn8906...
# 1433  https://chroniclingamerica.loc.gov/lccn/sn9005...
# 1434  https://chroniclingamerica.loc.gov/lccn/sn8200...
# 1435  https://chroniclingamerica.loc.gov/lccn/sn9005...
#
# [1436 rows x 2 columns]

# %% [markdown]
# ### 2) Scrape results of the URL search scrape to get your actual newspaper data
#
# Now, using our dataframe of urls from ChronAm that lead to ocr pages of newspapers that contain relevant search results, we can scrape those urls using the same function send_request_with_retry. Then we'll put those scraped results into our dataframe.

# %%
# to keep track of how long the program takes to run
start_time = datetime.now()

# take the "URL" column from df and save it as urls
urls = df["URL"]

# another shell for scraped content
newspaper_content = []

# Iterate over each URL in the urls
for url in urls:
    
    try:
        # Send a request to the URL using our function that accounts for rate limits and errors
        response = send_request_with_retry(url)
        
        # Check if the request was successful
        if response.status_code == 200:
            # Parse the HTML content using BeautifulSoup to get just newspaper text
            soup = BeautifulSoup(response.text, 'html.parser')
            
            p_tags = soup.find_all('p')
            p_text = ' '.join([tag.get_text(strip=True) for tag in p_tags])
            
            # add the extracted text to the list
            newspaper_content.append(p_text)
            
        else:
            # If request fails, leave url instance blank
            newspaper_content.append(None)
            
    except Exception as e:
        # Handle any other exceptions that occur during the scrape by leaving url instance blank
        newspaper_content.append(None)

# Calculate and print the total elapsed time. This may be useful to help you know how long it takes to scrape.
end_time = datetime.now()
total_elapsed_time = end_time - start_time
print(f"Total elapsed time: {total_elapsed_time}")

# Add the scraped content as a new column in df called 'text'
df['text'] = newspaper_content
# Out:
# Requests made: 3
# Requests made: 4
# Requests made: 5
# Requests made: 6
# Requests made: 7
# Requests made: 8
# Requests made: 9
# Requests made: 10
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 11
# Requests made: 12
# Requests made: 13
# Requests made: 14
# Requests made: 15
# Requests made: 16
# Requests made: 17
# Requests made: 18
# Requests made: 19
# Requests made: 20
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 21
# Requests made: 22
# Requests made: 23
# Requests made: 24
# Requests made: 25
# Requests made: 26
# Requests made: 27
# Requests made: 28
# Requests made: 29
# Requests made: 30
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 31
# Requests made: 32
# Requests made: 33
# Requests made: 34
# Requests made: 35
# Requests made: 36
# Requests made: 37
# Requests made: 38
# Requests made: 39
# Requests made: 40
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 41
# Requests made: 42
# Requests made: 43
# Requests made: 44
# Requests made: 45
# Requests made: 46
# Requests made: 47
# Requests made: 48
# Requests made: 49
# Requests made: 50
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 51
# Requests made: 52
# Requests made: 53
# Requests made: 54
# Requests made: 55
# Requests made: 56
# Requests made: 57
# Requests made: 58
# Requests made: 59
# Requests made: 60
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 61
# Requests made: 62
# Requests made: 63
# Requests made: 64
# Requests made: 65
# Requests made: 66
# Requests made: 67
# Requests made: 68
# Requests made: 69
# Requests made: 70
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 71
# Requests made: 72
# Requests made: 73
# Requests made: 74
# Requests made: 75
# Requests made: 76
# Requests made: 77
# Requests made: 78
# Requests made: 79
# Requests made: 80
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 81
# Requests made: 82
# Requests made: 83
# Requests made: 84
# Requests made: 85
# Requests made: 86
# Requests made: 87
# Requests made: 88
# Requests made: 89
# Requests made: 90
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 91
# Requests made: 92
# Requests made: 93
# Requests made: 94
# Requests made: 95
# Requests made: 96
# Requests made: 97
# Requests made: 98
# Requests made: 99
# Requests made: 100
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 101
# Requests made: 102
# Requests made: 103
# Requests made: 104
# Requests made: 105
# Requests made: 106
# Requests made: 107
# Requests made: 108
# Requests made: 109
# Requests made: 110
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 111
# Requests made: 112
# Requests made: 113
# Requests made: 114
# Requests made: 115
# Requests made: 116
# Requests made: 117
# Requests made: 118
# Requests made: 119
# Requests made: 120
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 121
# Requests made: 122
# Requests made: 123
# Requests made: 124
# Requests made: 125
# Requests made: 126
# Requests made: 127
# Requests made: 128
# Requests made: 129
# Requests made: 130
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 131
# Requests made: 132
# Requests made: 133
# Requests made: 134
# Requests made: 135
# Requests made: 136
# Requests made: 137
# Requests made: 138
# Requests made: 139
# Requests made: 140
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 141
# Requests made: 142
# Requests made: 143
# Requests made: 144
# Requests made: 145
# Requests made: 146
# Requests made: 147
# Requests made: 148
# Requests made: 149
# Requests made: 150
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 151
# Requests made: 152
# Requests made: 153
# Requests made: 154
# Requests made: 155
# Requests made: 156
# Requests made: 157
# Requests made: 158
# Requests made: 159
# Requests made: 160
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 161
# Requests made: 162
# Requests made: 163
# Requests made: 164
# Requests made: 165
# Requests made: 166
# Requests made: 167
# Requests made: 168
# Requests made: 169
# Requests made: 170
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 171
# Requests made: 172
# Requests made: 173
# Requests made: 174
# Requests made: 175
# Requests made: 176
# Requests made: 177
# Requests made: 178
# Requests made: 179
# Requests made: 180
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 181
# Requests made: 182
# Requests made: 183
# Requests made: 184
# Requests made: 185
# Requests made: 186
# Requests made: 187
# Requests made: 188
# Requests made: 189
# Requests made: 190
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 191
# Requests made: 192
# Requests made: 193
# Requests made: 194
# Requests made: 195
# Requests made: 196
# Requests made: 197
# Requests made: 198
# Requests made: 199
# Requests made: 200
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 201
# Requests made: 202
# Requests made: 203
# Requests made: 204
# Requests made: 205
# Requests made: 206
# Requests made: 207
# Requests made: 208
# Requests made: 209
# Requests made: 210
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 211
# Requests made: 212
# Requests made: 213
# Requests made: 214
# Requests made: 215
# Requests made: 216
# Requests made: 217
# Requests made: 218
# Requests made: 219
# Requests made: 220
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 221
# Requests made: 222
# Requests made: 223
# Requests made: 224
# Requests made: 225
# Requests made: 226
# Requests made: 227
# Requests made: 228
# Requests made: 229
# Requests made: 230
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 231
# Requests made: 232
# Requests made: 233
# Requests made: 234
# Requests made: 235
# Requests made: 236
# Requests made: 237
# Requests made: 238
# Requests made: 239
# Requests made: 240
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 241
# Requests made: 242
# Requests made: 243
# Requests made: 244
# Requests made: 245
# Requests made: 246
# Requests made: 247
# Requests made: 248
# Requests made: 249
# Requests made: 250
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 251
# Requests made: 252
# Requests made: 253
# Requests made: 254
# Requests made: 255
# Requests made: 256
# Requests made: 257
# Requests made: 258
# Requests made: 259
# Requests made: 260
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 261
# Requests made: 262
# Requests made: 263
# Requests made: 264
# Requests made: 265
# Requests made: 266
# Requests made: 267
# Requests made: 268
# Requests made: 269
# Requests made: 270
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 271
# Requests made: 272
# Requests made: 273
# Requests made: 274
# Requests made: 275
# Requests made: 276
# Requests made: 277
# Requests made: 278
# Requests made: 279
# Requests made: 280
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 281
# Requests made: 282
# Requests made: 283
# Requests made: 284
# Requests made: 285
# Requests made: 286
# Requests made: 287
# Requests made: 288
# Requests made: 289
# Requests made: 290
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 291
# Requests made: 292
# Requests made: 293
# Requests made: 294
# Requests made: 295
# Requests made: 296
# Requests made: 297
# Requests made: 298
# Requests made: 299
# Requests made: 300
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 301
# Requests made: 302
# Requests made: 303
# Requests made: 304
# Requests made: 305
# Requests made: 306
# Requests made: 307
# Requests made: 308
# Requests made: 309
# Requests made: 310
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 311
# Requests made: 312
# Requests made: 313
# Requests made: 314
# Requests made: 315
# Requests made: 316
# Requests made: 317
# Requests made: 318
# Requests made: 319
# Requests made: 320
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 321
# Requests made: 322
# Requests made: 323
# Requests made: 324
# Requests made: 325
# Requests made: 326
# Requests made: 327
# Requests made: 328
# Requests made: 329
# Requests made: 330
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 331
# Requests made: 332
# Requests made: 333
# Requests made: 334
# Requests made: 335
# Requests made: 336
# Requests made: 337
# Requests made: 338
# Requests made: 339
# Requests made: 340
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 341
# Requests made: 342
# Requests made: 343
# Requests made: 344
# Requests made: 345
# Requests made: 346
# Requests made: 347
# Requests made: 348
# Requests made: 349
# Requests made: 350
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 351
# Requests made: 352
# Requests made: 353
# Requests made: 354
# Requests made: 355
# Requests made: 356
# Requests made: 357
# Requests made: 358
# Requests made: 359
# Requests made: 360
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 361
# Requests made: 362
# Requests made: 363
# Requests made: 364
# Requests made: 365
# Requests made: 366
# Requests made: 367
# Requests made: 368
# Requests made: 369
# Requests made: 370
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 371
# Requests made: 372
# Requests made: 373
# Requests made: 374
# Requests made: 375
# Requests made: 376
# Requests made: 377
# Requests made: 378
# Requests made: 379
# Requests made: 380
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 381
# Requests made: 382
# Requests made: 383
# Requests made: 384
# Requests made: 385
# Requests made: 386
# Requests made: 387
# Requests made: 388
# Requests made: 389
# Requests made: 390
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 391
# Requests made: 392
# Requests made: 393
# Requests made: 394
# Requests made: 395
# Requests made: 396
# Requests made: 397
# Requests made: 398
# Requests made: 399
# Requests made: 400
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 401
# Requests made: 402
# Requests made: 403
# Requests made: 404
# Requests made: 405
# Requests made: 406
# Requests made: 407
# Requests made: 408
# Requests made: 409
# Requests made: 410
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 411
# Requests made: 412
# Requests made: 413
# Requests made: 414
# Requests made: 415
# Requests made: 416
# Requests made: 417
# Requests made: 418
# Requests made: 419
# Requests made: 420
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 421
# Requests made: 422
# Requests made: 423
# Requests made: 424
# Requests made: 425
# Requests made: 426
# Requests made: 427
# Requests made: 428
# Requests made: 429
# Requests made: 430
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 431
# Requests made: 432
# Requests made: 433
# Requests made: 434
# Requests made: 435
# Requests made: 436
# Requests made: 437
# Requests made: 438
# Requests made: 439
# Requests made: 440
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 441
# Requests made: 442
# Requests made: 443
# Requests made: 444
# Requests made: 445
# Requests made: 446
# Requests made: 447
# Requests made: 448
# Requests made: 449
# Requests made: 450
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 451
# Requests made: 452
# Requests made: 453
# Requests made: 454
# Requests made: 455
# Requests made: 456
# Requests made: 457
# Requests made: 458
# Requests made: 459
# Requests made: 460
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 461
# Requests made: 462
# Requests made: 463
# Requests made: 464
# Requests made: 465
# Requests made: 466
# Requests made: 467
# Requests made: 468
# Requests made: 469
# Requests made: 470
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 471
# Requests made: 472
# Requests made: 473
# Requests made: 474
# Requests made: 475
# Requests made: 476
# Requests made: 477
# Requests made: 478
# Requests made: 479
# Requests made: 480
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 481
# Requests made: 482
# Requests made: 483
# Requests made: 484
# Requests made: 485
# Requests made: 486
# Requests made: 487
# Requests made: 488
# Requests made: 489
# Requests made: 490
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 491
# Requests made: 492
# Requests made: 493
# Requests made: 494
# Requests made: 495
# Requests made: 496
# Requests made: 497
# Requests made: 498
# Requests made: 499
# Requests made: 500
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 501
# Requests made: 502
# Requests made: 503
# Requests made: 504
# Requests made: 505
# Requests made: 506
# Requests made: 507
# Requests made: 508
# Requests made: 509
# Requests made: 510
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 511
# Requests made: 512
# Requests made: 513
# Requests made: 514
# Requests made: 515
# Requests made: 516
# Requests made: 517
# Requests made: 518
# Requests made: 519
# Requests made: 520
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 521
# Requests made: 522
# Requests made: 523
# Requests made: 524
# Requests made: 525
# Requests made: 526
# Requests made: 527
# Requests made: 528
# Requests made: 529
# Requests made: 530
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 531
# Requests made: 532
# Requests made: 533
# Requests made: 534
# Requests made: 535
# Requests made: 536
# Requests made: 537
# Requests made: 538
# Requests made: 539
# Requests made: 540
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 541
# Requests made: 542
# Requests made: 543
# Requests made: 544
# Requests made: 545
# Requests made: 546
# Requests made: 547
# Requests made: 548
# Requests made: 549
# Requests made: 550
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 551
# Requests made: 552
# Requests made: 553
# Requests made: 554
# Requests made: 555
# Requests made: 556
# Requests made: 557
# Requests made: 558
# Requests made: 559
# Requests made: 560
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 561
# Requests made: 562
# Requests made: 563
# Requests made: 564
# Requests made: 565
# Requests made: 566
# Requests made: 567
# Requests made: 568
# Requests made: 569
# Requests made: 570
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 571
# Requests made: 572
# Requests made: 573
# Requests made: 574
# Requests made: 575
# Requests made: 576
# Requests made: 577
# Requests made: 578
# Requests made: 579
# Requests made: 580
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 581
# Requests made: 582
# Requests made: 583
# Requests made: 584
# Requests made: 585
# Requests made: 586
# Requests made: 587
# Requests made: 588
# Requests made: 589
# Requests made: 590
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 591
# Requests made: 592
# Requests made: 593
# Requests made: 594
# Requests made: 595
# Requests made: 596
# Requests made: 597
# Requests made: 598
# Requests made: 599
# Requests made: 600
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 601
# Requests made: 602
# Requests made: 603
# Requests made: 604
# Requests made: 605
# Requests made: 606
# Requests made: 607
# Requests made: 608
# Requests made: 609
# Requests made: 610
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 611
# Requests made: 612
# Requests made: 613
# Requests made: 614
# Requests made: 615
# Requests made: 616
# Requests made: 617
# Requests made: 618
# Requests made: 619
# Requests made: 620
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 621
# Requests made: 622
# Requests made: 623
# Requests made: 624
# Requests made: 625
# Requests made: 626
# Requests made: 627
# Requests made: 628
# Requests made: 629
# Requests made: 630
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 631
# Requests made: 632
# Requests made: 633
# Requests made: 634
# Requests made: 635
# Requests made: 636
# Requests made: 637
# Requests made: 638
# Requests made: 639
# Requests made: 640
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 641
# Requests made: 642
# Requests made: 643
# Requests made: 644
# Requests made: 645
# Requests made: 646
# Requests made: 647
# Requests made: 648
# Requests made: 649
# Requests made: 650
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 651
# Requests made: 652
# Requests made: 653
# Requests made: 654
# Requests made: 655
# Requests made: 656
# Requests made: 657
# Requests made: 658
# Requests made: 659
# Requests made: 660
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 661
# Requests made: 662
# Requests made: 663
# Requests made: 664
# Requests made: 665
# Requests made: 666
# Requests made: 667
# Requests made: 668
# Requests made: 669
# Requests made: 670
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 671
# Requests made: 672
# Requests made: 673
# Requests made: 674
# Requests made: 675
# Requests made: 676
# Requests made: 677
# Requests made: 678
# Requests made: 679
# Requests made: 680
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 681
# Requests made: 682
# Requests made: 683
# Requests made: 684
# Requests made: 685
# Requests made: 686
# Requests made: 687
# Requests made: 688
# Requests made: 689
# Requests made: 690
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 691
# Requests made: 692
# Requests made: 693
# Requests made: 694
# Requests made: 695
# Requests made: 696
# Requests made: 697
# Requests made: 698
# Requests made: 699
# Requests made: 700
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 701
# Requests made: 702
# Requests made: 703
# Requests made: 704
# Requests made: 705
# Requests made: 706
# Requests made: 707
# Requests made: 708
# Requests made: 709
# Requests made: 710
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 711
# Requests made: 712
# Requests made: 713
# Requests made: 714
# Requests made: 715
# Requests made: 716
# Requests made: 717
# Requests made: 718
# Requests made: 719
# Requests made: 720
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 721
# Requests made: 722
# Requests made: 723
# Requests made: 724
# Requests made: 725
# Requests made: 726
# Requests made: 727
# Requests made: 728
# Requests made: 729
# Requests made: 730
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 731
# Requests made: 732
# Requests made: 733
# Requests made: 734
# Requests made: 735
# Requests made: 736
# Requests made: 737
# Requests made: 738
# Requests made: 739
# Requests made: 740
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 741
# Requests made: 742
# Requests made: 743
# Requests made: 744
# Requests made: 745
# Requests made: 746
# Requests made: 747
# Requests made: 748
# Requests made: 749
# Requests made: 750
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 751
# Requests made: 752
# Requests made: 753
# Requests made: 754
# Requests made: 755
# Requests made: 756
# Requests made: 757
# Requests made: 758
# Requests made: 759
# Requests made: 760
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 761
# Requests made: 762
# Requests made: 763
# Requests made: 764
# Requests made: 765
# Requests made: 766
# Requests made: 767
# Requests made: 768
# Requests made: 769
# Requests made: 770
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 771
# Requests made: 772
# Requests made: 773
# Requests made: 774
# Requests made: 775
# Requests made: 776
# Requests made: 777
# Requests made: 778
# Requests made: 779
# Requests made: 780
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 781
# Requests made: 782
# Requests made: 783
# Requests made: 784
# Requests made: 785
# Requests made: 786
# Requests made: 787
# Requests made: 788
# Requests made: 789
# Requests made: 790
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 791
# Requests made: 792
# Requests made: 793
# Requests made: 794
# Requests made: 795
# Requests made: 796
# Requests made: 797
# Requests made: 798
# Requests made: 799
# Requests made: 800
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 801
# Requests made: 802
# Requests made: 803
# Requests made: 804
# Requests made: 805
# Requests made: 806
# Requests made: 807
# Requests made: 808
# Requests made: 809
# Requests made: 810
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 811
# Requests made: 812
# Requests made: 813
# Requests made: 814
# Requests made: 815
# Requests made: 816
# Requests made: 817
# Requests made: 818
# Requests made: 819
# Requests made: 820
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 821
# Requests made: 822
# Requests made: 823
# Requests made: 824
# Requests made: 825
# Requests made: 826
# Requests made: 827
# Requests made: 828
# Requests made: 829
# Requests made: 830
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 831
# Requests made: 832
# Requests made: 833
# Requests made: 834
# Requests made: 835
# Requests made: 836
# Requests made: 837
# Requests made: 838
# Requests made: 839
# Requests made: 840
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 841
# Requests made: 842
# Requests made: 843
# Requests made: 844
# Requests made: 845
# Requests made: 846
# Requests made: 847
# Requests made: 848
# Requests made: 849
# Requests made: 850
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 851
# Requests made: 852
# Requests made: 853
# Requests made: 854
# Requests made: 855
# Requests made: 856
# Requests made: 857
# Requests made: 858
# Requests made: 859
# Requests made: 860
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 861
# Requests made: 862
# Requests made: 863
# Requests made: 864
# Requests made: 865
# Requests made: 866
# Requests made: 867
# Requests made: 868
# Requests made: 869
# Requests made: 870
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 871
# Requests made: 872
# Requests made: 873
# Requests made: 874
# Requests made: 875
# Requests made: 876
# Requests made: 877
# Requests made: 878
# Requests made: 879
# Requests made: 880
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 881
# Requests made: 882
# Requests made: 883
# Requests made: 884
# Requests made: 885
# Requests made: 886
# Requests made: 887
# Requests made: 888
# Requests made: 889
# Requests made: 890
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 891
# Requests made: 892
# Requests made: 893
# Requests made: 894
# Requests made: 895
# Requests made: 896
# Requests made: 897
# Requests made: 898
# Requests made: 899
# Requests made: 900
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 901
# Requests made: 902
# Requests made: 903
# Requests made: 904
# Requests made: 905
# Requests made: 906
# Requests made: 907
# Requests made: 908
# Requests made: 909
# Requests made: 910
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 911
# Requests made: 912
# Requests made: 913
# Requests made: 914
# Requests made: 915
# Requests made: 916
# Requests made: 917
# Requests made: 918
# Requests made: 919
# Requests made: 920
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 921
# Requests made: 922
# Requests made: 923
# Requests made: 924
# Requests made: 925
# Requests made: 926
# Requests made: 927
# Requests made: 928
# Requests made: 929
# Requests made: 930
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 931
# Requests made: 932
# Requests made: 933
# Requests made: 934
# Requests made: 935
# Requests made: 936
# Requests made: 937
# Requests made: 938
# Requests made: 939
# Requests made: 940
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 941
# Requests made: 942
# Requests made: 943
# Requests made: 944
# Requests made: 945
# Requests made: 946
# Requests made: 947
# Requests made: 948
# Requests made: 949
# Requests made: 950
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 951
# Requests made: 952
# Requests made: 953
# Requests made: 954
# Requests made: 955
# Requests made: 956
# Requests made: 957
# Requests made: 958
# Requests made: 959
# Requests made: 960
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 961
# Requests made: 962
# Requests made: 963
# Requests made: 964
# Requests made: 965
# Requests made: 966
# Requests made: 967
# Requests made: 968
# Requests made: 969
# Requests made: 970
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 971
# Requests made: 972
# Requests made: 973
# Requests made: 974
# Requests made: 975
# Requests made: 976
# Requests made: 977
# Requests made: 978
# Requests made: 979
# Requests made: 980
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 981
# Requests made: 982
# Requests made: 983
# Requests made: 984
# Requests made: 985
# Requests made: 986
# Requests made: 987
# Requests made: 988
# Requests made: 989
# Requests made: 990
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 991
# Requests made: 992
# Requests made: 993
# Requests made: 994
# Requests made: 995
# Requests made: 996
# Requests made: 997
# Requests made: 998
# Requests made: 999
# Requests made: 1000
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1001
# Requests made: 1002
# Requests made: 1003
# Requests made: 1004
# Requests made: 1005
# Requests made: 1006
# Requests made: 1007
# Requests made: 1008
# Requests made: 1009
# Requests made: 1010
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1011
# Requests made: 1012
# Requests made: 1013
# Requests made: 1014
# Requests made: 1015
# Requests made: 1016
# Requests made: 1017
# Requests made: 1018
# Requests made: 1019
# Requests made: 1020
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1021
# Requests made: 1022
# Requests made: 1023
# Requests made: 1024
# Requests made: 1025
# Requests made: 1026
# Requests made: 1027
# Requests made: 1028
# Requests made: 1029
# Requests made: 1030
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1031
# Requests made: 1032
# Requests made: 1033
# Requests made: 1034
# Requests made: 1035
# Requests made: 1036
# Requests made: 1037
# Requests made: 1038
# Requests made: 1039
# Requests made: 1040
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1041
# Requests made: 1042
# Requests made: 1043
# Requests made: 1044
# Requests made: 1045
# Requests made: 1046
# Requests made: 1047
# Requests made: 1048
# Requests made: 1049
# Requests made: 1050
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1051
# Requests made: 1052
# Requests made: 1053
# Requests made: 1054
# Requests made: 1055
# Requests made: 1056
# Requests made: 1057
# Requests made: 1058
# Requests made: 1059
# Requests made: 1060
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1061
# Requests made: 1062
# Requests made: 1063
# Requests made: 1064
# Requests made: 1065
# Requests made: 1066
# Requests made: 1067
# Requests made: 1068
# Requests made: 1069
# Requests made: 1070
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1071
# Requests made: 1072
# Requests made: 1073
# Requests made: 1074
# Requests made: 1075
# Requests made: 1076
# Requests made: 1077
# Requests made: 1078
# Requests made: 1079
# Requests made: 1080
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1081
# Requests made: 1082
# Requests made: 1083
# Requests made: 1084
# Requests made: 1085
# Requests made: 1086
# Requests made: 1087
# Requests made: 1088
# Requests made: 1089
# Requests made: 1090
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1091
# Requests made: 1092
# Requests made: 1093
# Requests made: 1094
# Requests made: 1095
# Requests made: 1096
# Requests made: 1097
# Requests made: 1098
# Requests made: 1099
# Requests made: 1100
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1101
# Requests made: 1102
# Requests made: 1103
# Requests made: 1104
# Requests made: 1105
# Requests made: 1106
# Requests made: 1107
# Requests made: 1108
# Requests made: 1109
# Requests made: 1110
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1111
# Requests made: 1112
# Requests made: 1113
# Requests made: 1114
# Requests made: 1115
# Requests made: 1116
# Requests made: 1117
# Requests made: 1118
# Requests made: 1119
# Requests made: 1120
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1121
# Requests made: 1122
# Requests made: 1123
# Requests made: 1124
# Requests made: 1125
# Requests made: 1126
# Requests made: 1127
# Requests made: 1128
# Requests made: 1129
# Requests made: 1130
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1131
# Requests made: 1132
# Requests made: 1133
# Requests made: 1134
# Requests made: 1135
# Requests made: 1136
# Requests made: 1137
# Requests made: 1138
# Requests made: 1139
# Requests made: 1140
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1141
# Requests made: 1142
# Requests made: 1143
# Requests made: 1144
# Requests made: 1145
# Requests made: 1146
# Requests made: 1147
# Requests made: 1148
# Requests made: 1149
# Requests made: 1150
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1151
# Requests made: 1152
# Requests made: 1153
# Requests made: 1154
# Requests made: 1155
# Requests made: 1156
# Requests made: 1157
# Requests made: 1158
# Requests made: 1159
# Requests made: 1160
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1161
# Requests made: 1162
# Requests made: 1163
# Requests made: 1164
# Requests made: 1165
# Requests made: 1166
# Requests made: 1167
# Requests made: 1168
# Requests made: 1169
# Requests made: 1170
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1171
# Requests made: 1172
# Requests made: 1173
# Requests made: 1174
# Requests made: 1175
# Requests made: 1176
# Requests made: 1177
# Requests made: 1178
# Requests made: 1179
# Requests made: 1180
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1181
# Requests made: 1182
# Requests made: 1183
# Requests made: 1184
# Requests made: 1185
# Requests made: 1186
# Requests made: 1187
# Requests made: 1188
# Requests made: 1189
# Requests made: 1190
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1191
# Requests made: 1192
# Requests made: 1193
# Requests made: 1194
# Requests made: 1195
# Requests made: 1196
# Requests made: 1197
# Requests made: 1198
# Requests made: 1199
# Requests made: 1200
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1201
# Requests made: 1202
# Requests made: 1203
# Requests made: 1204
# Requests made: 1205
# Requests made: 1206
# Requests made: 1207
# Requests made: 1208
# Requests made: 1209
# Requests made: 1210
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1211
# Requests made: 1212
# Requests made: 1213
# Requests made: 1214
# Requests made: 1215
# Requests made: 1216
# Requests made: 1217
# Requests made: 1218
# Requests made: 1219
# Requests made: 1220
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1221
# Requests made: 1222
# Requests made: 1223
# Requests made: 1224
# Requests made: 1225
# Requests made: 1226
# Requests made: 1227
# Requests made: 1228
# Requests made: 1229
# Requests made: 1230
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1231
# Requests made: 1232
# Requests made: 1233
# Requests made: 1234
# Requests made: 1235
# Requests made: 1236
# Requests made: 1237
# Requests made: 1238
# Requests made: 1239
# Requests made: 1240
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1241
# Requests made: 1242
# Requests made: 1243
# Requests made: 1244
# Requests made: 1245
# Requests made: 1246
# Requests made: 1247
# Requests made: 1248
# Requests made: 1249
# Requests made: 1250
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1251
# Requests made: 1252
# Requests made: 1253
# Requests made: 1254
# Requests made: 1255
# Requests made: 1256
# Requests made: 1257
# Requests made: 1258
# Requests made: 1259
# Requests made: 1260
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1261
# Requests made: 1262
# Requests made: 1263
# Requests made: 1264
# Requests made: 1265
# Requests made: 1266
# Requests made: 1267
# Requests made: 1268
# Requests made: 1269
# Requests made: 1270
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1271
# Requests made: 1272
# Requests made: 1273
# Requests made: 1274
# Requests made: 1275
# Requests made: 1276
# Requests made: 1277
# Requests made: 1278
# Requests made: 1279
# Requests made: 1280
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1281
# Requests made: 1282
# Requests made: 1283
# Requests made: 1284
# Requests made: 1285
# Requests made: 1286
# Requests made: 1287
# Requests made: 1288
# Requests made: 1289
# Requests made: 1290
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1291
# Requests made: 1292
# Requests made: 1293
# Requests made: 1294
# Requests made: 1295
# Requests made: 1296
# Requests made: 1297
# Requests made: 1298
# Requests made: 1299
# Requests made: 1300
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1301
# Requests made: 1302
# Requests made: 1303
# Requests made: 1304
# Requests made: 1305
# Requests made: 1306
# Requests made: 1307
# Requests made: 1308
# Requests made: 1309
# Requests made: 1310
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1311
# Requests made: 1312
# Requests made: 1313
# Requests made: 1314
# Requests made: 1315
# Requests made: 1316
# Requests made: 1317
# Requests made: 1318
# Requests made: 1319
# Requests made: 1320
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1321
# Requests made: 1322
# Requests made: 1323
# Requests made: 1324
# Requests made: 1325
# Requests made: 1326
# Requests made: 1327
# Requests made: 1328
# Requests made: 1329
# Requests made: 1330
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1331
# Requests made: 1332
# Requests made: 1333
# Requests made: 1334
# Requests made: 1335
# Requests made: 1336
# Requests made: 1337
# Requests made: 1338
# Requests made: 1339
# Requests made: 1340
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1341
# Requests made: 1342
# Requests made: 1343
# Requests made: 1344
# Requests made: 1345
# Requests made: 1346
# Requests made: 1347
# Requests made: 1348
# Requests made: 1349
# Requests made: 1350
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1351
# Requests made: 1352
# Requests made: 1353
# Requests made: 1354
# Requests made: 1355
# Requests made: 1356
# Requests made: 1357
# Requests made: 1358
# Requests made: 1359
# Requests made: 1360
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1361
# Requests made: 1362
# Requests made: 1363
# Requests made: 1364
# Requests made: 1365
# Requests made: 1366
# Requests made: 1367
# Requests made: 1368
# Requests made: 1369
# Requests made: 1370
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1371
# Requests made: 1372
# Requests made: 1373
# Requests made: 1374
# Requests made: 1375
# Requests made: 1376
# Requests made: 1377
# Requests made: 1378
# Requests made: 1379
# Requests made: 1380
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1381
# Requests made: 1382
# Requests made: 1383
# Requests made: 1384
# Requests made: 1385
# Requests made: 1386
# Requests made: 1387
# Requests made: 1388
# Requests made: 1389
# Requests made: 1390
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1391
# Requests made: 1392
# Requests made: 1393
# Requests made: 1394
# Requests made: 1395
# Requests made: 1396
# Requests made: 1397
# Requests made: 1398
# Requests made: 1399
# Requests made: 1400
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1401
# Requests made: 1402
# Requests made: 1403
# Requests made: 1404
# Requests made: 1405
# Requests made: 1406
# Requests made: 1407
# Requests made: 1408
# Requests made: 1409
# Requests made: 1410
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1411
# Requests made: 1412
# Requests made: 1413
# Requests made: 1414
# Requests made: 1415
# Requests made: 1416
# Requests made: 1417
# Requests made: 1418
# Requests made: 1419
# Requests made: 1420
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1421
# Requests made: 1422
# Requests made: 1423
# Requests made: 1424
# Requests made: 1425
# Requests made: 1426
# Requests made: 1427
# Requests made: 1428
# Requests made: 1429
# Requests made: 1430
# Burst limit reached. Waiting for 5 seconds...
# Requests made: 1431
# Requests made: 1432
# Requests made: 1433
# Requests made: 1434
# Requests made: 1435
# Requests made: 1436
# Requests made: 1437
# Requests made: 1438
# Total elapsed time: 0:15:10.480537

# %% [markdown]
# And after some time, you'll have a df with all the pages of your search results:

# %%
df.head()
# Out:
#                                           Link Title  \
# 0  The Minnesota pioneer. [volume](St. Paul, Minn...
# 1  The Minnesota pioneer. [volume](St. Paul, Minn...
# 2  Minnesota weekly times. [volume](St. Paul, Min...
# 3  The weekly Minnesotian. [volume](Saint Paul, M...
# 4  Minnesota weekly times. [volume](St. Paul, Min...
#
#                                                  URL  \
# 0  https://chroniclingamerica.loc.gov/lccn/sn8302...
# 1  https://chroniclingamerica.loc.gov/lccn/sn8302...
# 2  https://chroniclingamerica.loc.gov/lccn/sn8502...
# 3  https://chroniclingamerica.loc.gov/lccn/sn8301...
# 4  https://chroniclingamerica.loc.gov/lccn/sn8502...
#
#                                                 text
# 0  i? <«) w IC*it. Th\«e chartuing hoes were writ...
# 1  NEWADVERTISEMENTS.FOR SALK.TTIE lurfre three s...
# 2  tTlif Jpiiwstrta WkM>a (TimesNEWSON, MITCHELL ...
# 3  THE MINNESOTIAN.THURSDAY MORNING, JULY 6,1854....
# 4  (Tbf Minnesota (Wtedilo (Times.NEWSON, MITCHEL...

# %% [markdown]
# An example page:

# %%
df['text'][500]
# Out:
# '\\sfje-s.4\'I\'vibntxt.Published W ednesdaya.vjfc.0. aXEVJ2W®»Publisher.Official Paper of Storeas Gtaafa*The census year began Juno 1,1889,and will end May 81, 1890.Or. O. W. Holmes says it is better tobe 70 years young than 40 years old.At last the right word has been fotmdfor death by electricity. It is electricide.Admiral Porter had his 76th birthdayparty a few days ago. Gen. B. F. Butler sent regrets.There are at least thirty colleges thathad a perfectly quiet graduating andcommencement day. They were thedeaf mute schools.In all the national educational exhibitsat the Paris exposition the most prominent and interesting feature is the industrial and manual training display.They say that Woodruff, the Croninmurder confessor, has told at least onetruth in his multifarious stories. He hasadmitted that he is an indefatigable liar.Since President Harrison has been inoffice he has had one band of visitors whodid not annoy him. They were 126Dunkard brethren, recently. Not one ofthem wanted an office.The death of John Gilbert leaves yetalive only one of the famous old actorswho were contemporary with CharlotteCushman. This is James E. Murdoch,the Hamlet of a past generation. Mr.Murdoch is one year younger thanJohn Gilbert. His powers are undimmed. Mr. Murdoch is president of thePhiladelphia school of oratory.The Samoan Treaty.So we shall have to wait officially andformally till the meeting of the senatenext December before finding out theprovisions of the Samoan treaty at Berlin. The grapevine telegraph has, however, probably given a tolerably correotoutline of it. Through this source it isascertained that King Malietoa is to berestored to the throne, and will governthe islands under the joint protection ofthe United States and Germany. Shoulddifferences arise between the two protectors, England will settle them by arbi\'-*. -fThere will be a paHiament or congress,composed of two houses, the members tobe elected b~ the Samoans themselves.This congri ihall have the right to levycustoms «luties. But the United States,England and Germany are to be boundby a tariff schedule framed at the Berlinconference. Germany is to receive indemnity for losses in the late disturbances. It is uncertain under diplomaticusage whether the Berlin document is tobe called a treaty or an agreement.Whichever it is, however, it will not gointo effect until ratified by the UnitedStates senate.An Old Fashioned Fomtfi.Let us resurrect the old fashionedFourth this year. It is the centennialyear of our existence as a nation.Forty years ago every rural neighborhood had its basket picnic on the Fourth.Baskets were packed full of homemadedelicacies drawn from the overflowingabundance of fertile farms. Fatherstook their families in the great wagonor carriage, and all hied to some greengrove, shady and sweet. Perhaps therewas a procession of the Sunday schoolchildred along the village street in themorning. At their head the neighborhood brass band played "Yankee Doodle" or the "Star Spangled Banner," andeach father and mother thought theirchildren marched better than any others.At the grove the procession disbanded.The most popular preacher thereaboutsprayed eloquently that the blessing ofheaven might be upon thi3 country forever and forever, as it had been with thefathers in times past Then there waspatriotic singing by the church choir orthe home glee club. Then the man withthe best voice read the glorious oldDeclaration of Independence to his neighbors and friends. Every year this wasdone. It was done in order to familiarize the children with this immortal document. So it was thought the love of liberty, sacred and splendid, would be kindled in their young breasts and glowduring their lives. It was boys broughtup on the old fashioned Fourth of Julywho fought the battles of 1861. Whyare not the children now taught moreabout the Declaration of Independence?Sometimes there was an oration. Perhaps there were several speeches andmore flinging. Then the formal ceremonie ...

# %% [markdown]
# To save your df as a csv file, just change the csv title in the code below:

# %%
df.to_csv('ssb_mentions_mn_papers_1800-99.csv', index=False, encoding='utf-8')
