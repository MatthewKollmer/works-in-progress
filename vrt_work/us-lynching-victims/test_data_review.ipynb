# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('training_data/clippings_part_1_labelled.csv')
df2 = pd.read_csv('training_data/clippings_part_2_labelled.csv')
df3 = pd.read_csv('training_data/clippings_part_3_labelled.csv')
df4 = pd.read_csv('training_data/clippings_part_4_labelled.csv')
df5 = pd.read_csv('training_data/clippings_part_5_labelled.csv')
df6 = pd.read_csv('training_data/clippings_part_6_labelled.csv')
df7 = pd.read_csv('training_data/clippings_part_7_labelled.csv')
df8 = pd.read_csv('training_data/clippings_part_8_labelled.csv')
df9 = pd.read_csv('training_data/clippings_part_9_labelled.csv')
df10 = pd.read_csv('training_data/clippings_part_10_labelled.csv')

df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10], ignore_index=True)

# %%
len(df)
# Out:
# 1000

# %%
df.head()
# Out:
#                                            clippings  \
# 0  , ihe military andpolice were htirrinl to tile...
# 1  , fannie brown ; 19 , geo utc kern ; 21 , j w ...
# 2  * mv.riimer , charged wi hoe i ag an accessory...
# 3  the finest tea ever sold in tbls market . cau ...
# 4  ? water commissioner.james meikle . . $ 13.00t...
#
#                                                  url          victim  \
# 0  https://chroniclingamerica.loc.gov/lccn/sn8606...  oscar williams
# 1  https://chroniclingamerica.loc.gov/lccn/sn8502...   mary phillips
# 2  https://chroniclingamerica.loc.gov/lccn/sn8402...   owen anderson
# 3  https://chroniclingamerica.loc.gov/lccn/sn8705...   thomas little
# 4  https://chroniclingamerica.loc.gov/lccn/sn8505...      john miles
#
#   case_match
# 0        yes
# 1         no
# 2    unknown
# 3         no
# 4         no

# %%
counts = df['case_match'].value_counts()

counts = counts.plot(kind='bar', color='darkred')
counts.bar_label(counts.containers[0])
plt.title('Newspaper Clippings Labelled')
plt.xlabel('Does the clipping contain reference to a lynching?')
plt.xticks(rotation=0)
plt.ylabel('Count')
plt.show()

# %%
df['case_match'] = df['case_match'].replace('unkown', 'unknown')

# %%
counts = df['case_match'].value_counts()

counts = counts.plot(kind='bar', color='darkred')
counts.bar_label(counts.containers[0])
plt.title('Newspaper Clippings Labelled')
plt.xlabel('Does the clipping contain reference to a lynching?')
plt.xticks(rotation=0)
plt.ylabel('Count')
plt.show()
